# %%
import sys
sys.path.append("..")

# %%
from ethicml.algorithms.inprocess import LR, SVM, Majority, ZafarAccuracy, ZafarFairness, Kamiran, Agarwal
from ethicml.metrics import Accuracy, AbsCV, ProbPos, TPR, TNR, F1, BalancedAccuracy
from ethicml.preprocessing import BalancedTestSplit
from ethicml.evaluators import evaluate_models_async, load_results
from ethicml.data import Adult, load_data
from ethicml.visualisation import plot_results
from ethicml.utility import Results

# %%
from ethicml_models import DPFlags, TrainTrainSplit, TuningLr, TPRRatio, GPyTDemPar

# %%
use_s = False
results = await evaluate_models_async(
    datasets=[
        Adult(),
        Adult("Race-Binary"),
    ],
    inprocess_models=[
        LR(),
#         SVM(),
#         Majority(),
#         ZafarAccuracy(),
#         ZafarFairness(),
#         Kamiran(),
#         Agarwal(),

        TuningLr(use_s=use_s),
        TuningLr(fair=True, debiasing_args=DPFlags(target_rate_s0=0.1, target_rate_s1=0.1), use_s=use_s),
        TuningLr(fair=True, debiasing_args=DPFlags(target_rate_s0=0.2, target_rate_s1=0.2), use_s=use_s),
        TuningLr(fair=True, debiasing_args=DPFlags(target_rate_s0=0.3, target_rate_s1=0.3), use_s=use_s),
        TuningLr(fair=True, debiasing_args=DPFlags(target_rate_s0=0.4, target_rate_s1=0.4), use_s=use_s),
        TuningLr(fair=True, debiasing_args=DPFlags(target_rate_s0=0.5, target_rate_s1=0.5), use_s=use_s),
    ],
    metrics=[Accuracy(), AbsCV(), F1(), TPRRatio(), ProbPos(), TPR(), TNR(), BalancedAccuracy()],
    per_sens_metrics=[Accuracy(), ProbPos(), TPR(), TNR()],
    repeats=10,
    delete_prev=False,
    splitter=TrainTrainSplit(),
    topic="dp_traintrain_10repeats",
    max_parallel=3,
)
# Out:
# synchronous algorithms...
# 100%|██████████| 20/20 [00:06<00:00,  3.13it/s, model=Logistic Regression, C=1.0, dataset=Adult Race-Binary - Train (9)]
# asynchronous algorithms...
#  28%|██▊       | 34/120 [29:17<1:14:05, 51.69s/it, model=TuningLR, wd: 0.1, RAdam, PR_t: 0.1, dataset=Adult Race-Binary - Train (6), worker_id=1]

# %%
results = load_results("Adult Sex", "no_transform", topic="baselines_traintrain")

# %%
(fig, plot), = plot_results(results, "Accuracy", "prob_pos_sex_Male_0/sex_Male_1", ptype="cross")
fig

# %%
(fig, plot), = plot_results(results, "Balanced Accuracy", "prob_pos_sex_Male_0/sex_Male_1", ptype="cross")
fig

# %%
(fig, plot), = plot_results(results, "F1", "prob_pos_sex_Male_0/sex_Male_1", ptype="cross")
fig

# %%
(fig, plot), = plot_results(results, "Accuracy", "TPR_sex_Male_0/sex_Male_1", ptype="cross")
fig

# %%
(fig, plot), = plot_results(
    Results(results.data.query("model != 'Majority'")),
    "prob_pos_sex_Male_0", "prob_pos_sex_Male_1", ptype="cross")

plot.set_ylim((0.05, 0.35))
fig

# %%
(fig, plot), = plot_results(
    Results(results.data.query("model != 'Majority'")),
    "TPR", "TNR", ptype="cross")

# plot.set_ylim((0.05, 0.35))
fig

# %%
(fig, plot), = plot_results(
    Results(results.data.query("model != 'Majority'")),
    "TNR_sex_Male_0", "TNR_sex_Male_1", ptype="cross")

# plot.set_ylim((0.05, 0.35))
fig

# %%
results_temp = Results(results.data.query("model != 'TuningLR, wd: 0.1, RAdam, PR_t: 0.5' & model != 'Majority'"))
(fig, plot), = plot_results(results_temp, "Accuracy", "TNR_sex_Male_0/sex_Male_1", ptype="cross")
fig

# %%
results_temp.data
# Out:
#                                                                      Accuracy  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4         0.898775
#                        SVM                                 4         0.909323
#                        ZafarAccuracy, γ=0.5                4         0.862368
#                        ZafarFairness, c=0.001              4         0.900476
#                        Kamiran & Calders LR                4         0.899626
# ...                                                                       ...
#                        TuningLR, wd: 0.1, RAdam            4         0.878530
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4         0.887547
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         0.877339
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         0.859986
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         0.804866
#
#                                                                      Accuracy_sex_Male_0  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                    0.921742
#                        SVM                                 4                    0.927526
#                        ZafarAccuracy, γ=0.5                4                    0.862198
#                        ZafarFairness, c=0.001              4                    0.902007
#                        Kamiran & Calders LR                4                    0.910854
# ...                                                                                  ...
#                        TuningLR, wd: 0.1, RAdam            4                    0.920041
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                    0.900987
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                    0.896563
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                    0.876489
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                    0.838721
#
#                                                                      Accuracy_sex_Male_0-sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                               0.045934
#                        SVM                                 4                               0.036407
#                        ZafarAccuracy, γ=0.5                4                               0.000340
#                        ZafarFairness, c=0.001              4                               0.003062
#                        Kamiran & Calders LR                4                               0.022457
# ...                                                                                             ...
#                        TuningLR, wd: 0.1, RAdam            4                               0.083021
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                               0.026880
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                               0.038448
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                               0.033004
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                               0.067710
#
#                                                                      Accuracy_sex_Male_0/sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                               0.950166
#                        SVM                                 4                               0.960748
#                        ZafarAccuracy, γ=0.5                4                               0.999606
#                        ZafarFairness, c=0.001              4                               0.996605
#                        Kamiran & Calders LR                4                               0.975346
# ...                                                                                             ...
#                        TuningLR, wd: 0.1, RAdam            4                               0.909763
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                               0.970166
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                               0.957116
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                               0.962345
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                               0.919270
#
#                                                                      Accuracy_sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                    0.875808
#                        SVM                                 4                    0.891119
#                        ZafarAccuracy, γ=0.5                4                    0.862538
#                        ZafarFairness, c=0.001              4                    0.898945
#                        Kamiran & Calders LR                4                    0.888397
# ...                                                                                  ...
#                        TuningLR, wd: 0.1, RAdam            4                    0.837019
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                    0.874107
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                    0.858115
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                    0.843484
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                    0.771011
#
#                                                                      CV absolute  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4            0.919360
#                        SVM                                 4            0.913236
#                        ZafarAccuracy, γ=0.5                4            0.958830
#                        ZafarFairness, c=0.001              4            0.970398
#                        Kamiran & Calders LR                4            0.995917
# ...                                                                          ...
#                        TuningLR, wd: 0.1, RAdam            4            0.908132
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4            0.979925
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4            0.990133
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4            0.996938
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4            0.942497
#
#                                                                            F1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4         0.564103
#                        SVM                                 4         0.573259
#                        ZafarAccuracy, γ=0.5                4         0.453747
#                        ZafarFairness, c=0.001              4         0.589474
#                        Kamiran & Calders LR                4         0.589136
# ...                                                                       ...
#                        TuningLR, wd: 0.1, RAdam            4         0.531496
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4         0.326198
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         0.527213
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         0.508657
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         0.460235
#
#                                                                           TNR  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4         0.940115
#                        SVM                                 4         0.957198
#                        ZafarAccuracy, γ=0.5                4         0.908445
#                        ZafarFairness, c=0.001              4         0.935317
#                        Kamiran & Calders LR                4         0.933781
# ...                                                                       ...
#                        TuningLR, wd: 0.1, RAdam            4         0.913436
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4         0.970633
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         0.912668
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         0.888484
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         0.814203
#
#                                                                      TNR_sex_Male_0  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4               0.975816
#                        SVM                                 4               0.991939
#                        ZafarAccuracy, γ=0.5                4               0.896737
#                        ZafarFairness, c=0.001              4               0.927831
#                        Kamiran & Calders LR                4               0.941267
# ...                                                                             ...
#                        TuningLR, wd: 0.1, RAdam            4               0.962764
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4               0.983877
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4               0.926296
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4               0.898656
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4               0.849520
#
#                                                                      TNR_sex_Male_0-sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                          0.071401
#                        SVM                                 4                          0.069482
#                        ZafarAccuracy, γ=0.5                4                          0.023417
#                        ZafarFairness, c=0.001              4                          0.014971
#                        Kamiran & Calders LR                4                          0.014971
# ...                                                                                        ...
#                        TuningLR, wd: 0.1, RAdam            4                          0.098656
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                          0.026488
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                          0.027255
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                          0.020345
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                          0.070633
#
#                                                                      ...  \
# dataset   transform    model                               split_id  ...
# Adult Sex no_transform Logistic Regression, C=1.0          4         ...
#                        SVM                                 4         ...
#                        ZafarAccuracy, γ=0.5                4         ...
#                        ZafarFairness, c=0.001              4         ...
#                        Kamiran & Calders LR                4         ...
# ...                                                                  ...
#                        TuningLR, wd: 0.1, RAdam            4         ...
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4         ...
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         ...
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         ...
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         ...
#
#                                                                      percent_dropped  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                0.350177
#                        SVM                                 4                0.350177
#                        ZafarAccuracy, γ=0.5                4                0.350177
#                        ZafarFairness, c=0.001              4                0.350177
#                        Kamiran & Calders LR                4                0.350177
# ...                                                                              ...
#                        TuningLR, wd: 0.1, RAdam            4                0.350177
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                0.350177
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                0.350177
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                0.350177
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                0.350177
#
#                                                                      prob_pos  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4         0.118578
#                        SVM                                 4         0.098843
#                        ZafarAccuracy, γ=0.5                4         0.138312
#                        ZafarFairness, c=0.001              4         0.128785
#                        Kamiran & Calders LR                4         0.130657
# ...                                                                       ...
#                        TuningLR, wd: 0.1, RAdam            4         0.145628
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4         0.053249
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         0.145798
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         0.171317
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         0.247873
#
#                                                                      prob_pos_sex_Male_0  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                    0.078258
#                        SVM                                 4                    0.055461
#                        ZafarAccuracy, γ=0.5                4                    0.158898
#                        ZafarFairness, c=0.001              4                    0.143586
#                        Kamiran & Calders LR                4                    0.128615
# ...                                                                                  ...
#                        TuningLR, wd: 0.1, RAdam            4                    0.099694
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                    0.043212
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                    0.140864
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                    0.169786
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                    0.219122
#
#                                                                      prob_pos_sex_Male_0-sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                               0.080640
#                        SVM                                 4                               0.086764
#                        ZafarAccuracy, γ=0.5                4                               0.041170
#                        ZafarFairness, c=0.001              4                               0.029602
#                        Kamiran & Calders LR                4                               0.004083
# ...                                                                                             ...
#                        TuningLR, wd: 0.1, RAdam            4                               0.091868
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                               0.020075
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                               0.009867
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                               0.003062
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                               0.057503
#
#                                                                      prob_pos_sex_Male_0/sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                               0.492505
#                        SVM                                 4                               0.389952
#                        ZafarAccuracy, γ=0.5                4                               0.740899
#                        ZafarFairness, c=0.001              4                               0.793839
#                        Kamiran & Calders LR                4                               0.969231
# ...                                                                                             ...
#                        TuningLR, wd: 0.1, RAdam            4                               0.520426
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                               0.682796
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                               0.934537
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                               0.982283
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                               0.792128
#
#                                                                      prob_pos_sex_Male_1  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4                    0.158898
#                        SVM                                 4                    0.142225
#                        ZafarAccuracy, γ=0.5                4                    0.117727
#                        ZafarFairness, c=0.001              4                    0.113984
#                        Kamiran & Calders LR                4                    0.132698
# ...                                                                                  ...
#                        TuningLR, wd: 0.1, RAdam            4                    0.191562
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4                    0.063287
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4                    0.150732
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4                    0.172848
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4                    0.276625
#
#                                                                        seed  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4         9640.0
#                        SVM                                 4         9640.0
#                        ZafarAccuracy, γ=0.5                4         9640.0
#                        ZafarFairness, c=0.001              4         9640.0
#                        Kamiran & Calders LR                4         9640.0
# ...                                                                     ...
#                        TuningLR, wd: 0.1, RAdam            4         9640.0
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4         9640.0
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         9640.0
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         9640.0
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         9640.0
#
#                                                                      PR_t  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4          NaN
#                        SVM                                 4          NaN
#                        ZafarAccuracy, γ=0.5                4          NaN
#                        ZafarFairness, c=0.001              4          NaN
#                        Kamiran & Calders LR                4          NaN
# ...                                                                   ...
#                        TuningLR, wd: 0.1, RAdam            4          NaN
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4          0.1
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4          0.2
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4          0.3
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4          0.4
#
#                                                                          t_s0  \
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4              NaN
#                        SVM                                 4              NaN
#                        ZafarAccuracy, γ=0.5                4              NaN
#                        ZafarFairness, c=0.001              4              NaN
#                        Kamiran & Calders LR                4              NaN
# ...                                                                       ...
#                        TuningLR, wd: 0.1, RAdam            4              NaN
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4        -0.067795
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4         0.054026
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4         0.133172
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         0.238701
#
#                                                                          t_s1
# dataset   transform    model                               split_id
# Adult Sex no_transform Logistic Regression, C=1.0          4              NaN
#                        SVM                                 4              NaN
#                        ZafarAccuracy, γ=0.5                4              NaN
#                        ZafarFairness, c=0.001              4              NaN
#                        Kamiran & Calders LR                4              NaN
# ...                                                                       ...
#                        TuningLR, wd: 0.1, RAdam            4              NaN
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.1 4        -1.062385
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.2 4        -0.281192
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.3 4        -0.020795
#                        TuningLR, wd: 0.1, RAdam, PR_t: 0.4 4         0.072936
#
# [165 rows x 28 columns]

# %%
(fig, plot), = plot_results(results, "Accuracy", "TPR_sex_Male_0-sex_Male_1", ptype="cross")
fig

# %%
0.2*(0.58-0.08) + 0.08
# Out:
# 0.18
